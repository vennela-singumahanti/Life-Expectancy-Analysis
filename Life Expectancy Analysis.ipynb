# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Desktop/Life Expectancy Data.csv')
df
# Out:
#           Country  Year      Status  Life expectancy (men)  \
# 0     Afghanistan  2015  Developing                     70
# 1     Afghanistan  2014  Developing                     59
# 2     Afghanistan  2013  Developing                     79
# 3     Afghanistan  2012  Developing                     65
# 4     Afghanistan  2011  Developing                     76
# ...           ...   ...         ...                    ...
# 2933     Zimbabwe  2004  Developing                     67
# 2934     Zimbabwe  2003  Developing                     62
# 2935     Zimbabwe  2002  Developing                     50
# 2936     Zimbabwe  2001  Developing                     66
# 2937     Zimbabwe  2000  Developing                     55
#
#       Life expectancy(women)  Adult Mortality (men)  Adult Mortality (women)  \
# 0                         66                     67                       65
# 1                         67                     73                       85
# ...

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy (men)  \
# 0  Afghanistan  2015  Developing                     70
# 1  Afghanistan  2014  Developing                     59
# 2  Afghanistan  2013  Developing                     79
# 3  Afghanistan  2012  Developing                     65
# 4  Afghanistan  2011  Developing                     76
#
#    Life expectancy(women)  Adult Mortality (men)  Adult Mortality (women)  \
# 0                      66                     67                       65
# 1                      67                     73                       85
# 2                      51                     87                       67
# 3                      81                     63                       91
# 4                      75                     57                       72
#
#    Infant deaths  Alcohol  Percentage expenditure  ...  Polio  \
# 0             62     0.01               71.279624  ...    6.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 25 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy (men)            2938 non-null   int64
#  4   Life expectancy(women)           2938 non-null   int64
#  5   Adult Mortality (men)            2938 non-null   int64
#  6   Adult Mortality (women)          2938 non-null   int64
#  7   Infant deaths                    2938 non-null   int64
#  8   Alcohol                          2744 non-null   float64
#  9   Percentage expenditure           2938 non-null   float64
#  10  Hepatitis B(men)                 2938 non-null   int64
#  11  Hepatitis B(women)               2938 non-null   int64
# ...

# %%
df.shape
# Out:
# (2938, 25)

# %%
df.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy (men)                int64
# Life expectancy(women)               int64
# Adult Mortality (men)                int64
# Adult Mortality (women)              int64
# Infant deaths                        int64
# Alcohol                            float64
# Percentage expenditure             float64
# Hepatitis B(men)                     int64
# Hepatitis B(women)                   int64
# Measles                              int64
# BMI                                float64
# Under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
# HIV/AIDS                           float64
# GDP                                float64
# Population                         float64
# thinness  1-19 years               float64
# ...

# %% [markdown]
# **Finding null values of the data**

# %%
df.isnull().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy (men)                0
# Life expectancy(women)               0
# Adult Mortality (men)                0
# Adult Mortality (women)              0
# Infant deaths                        0
# Alcohol                            194
# Percentage expenditure               0
# Hepatitis B(men)                     0
# Hepatitis B(women)                   0
# Measles                              0
# BMI                                 34
# Under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         652
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# ...

# %% [markdown]
# **Count of missing values**

# %%
df.describe().T
# Out:
#                                   count          mean           std  \
# Year                             2938.0  2.007519e+03  4.613841e+00
# Life expectancy (men)            2938.0  6.771001e+01  1.034622e+01
# Life expectancy(women)           2938.0  6.762934e+01  1.032524e+01
# Adult Mortality (men)            2938.0  7.473281e+01  1.472887e+01
# Adult Mortality (women)          2938.0  7.455820e+01  1.468206e+01
# Infant deaths                    2938.0  3.030395e+01  1.179265e+02
# Alcohol                          2744.0  4.602861e+00  4.052413e+00
# Percentage expenditure           2938.0  7.382513e+02  1.987915e+03
# Hepatitis B(men)                 2938.0  4.601157e+01  1.655874e+01
# Hepatitis B(women)               2938.0  4.646971e+01  1.689127e+01
# Measles                          2938.0  2.419592e+03  1.146727e+04
# BMI                              2904.0  3.832125e+01  2.004403e+01
# Under-five deaths                2938.0  4.203574e+01  1.604455e+02
# ...

# %%
df.describe().sum()
# Out:
# Year                               1.498913e+04
# Life expectancy (men)              3.355056e+03
# Life expectancy(women)             3.353455e+03
# Adult Mortality (men)              3.400962e+03
# Adult Mortality (women)            3.400240e+03
# Infant deaths                      4.911230e+03
# Alcohol                            2.782870e+03
# Percentage expenditure             2.565521e+04
# Hepatitis B(men)                   3.230570e+03
# Hepatitis B(women)                 3.233361e+03
# Measles                            2.293851e+05
# BMI                                3.169665e+03
# Under-five deaths                  5.672481e+03
# Polio                              3.394978e+03
# Total expenditure                  2.755914e+03
# Diphtheria                         3.394041e+03
# HIV/AIDS                           2.996520e+03
# GDP                                1.515594e+05
# Population                         1.376630e+09
# thinness  1-19 years               2.953160e+03
# ...

# %% [markdown]
# **Finding Duplicate values**

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2933    False
# 2934    False
# 2935    False
# 2936    False
# 2937    False
# Length: 2938, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Convert year to datetime type**

# %%
df['Year'] = pd.to_datetime(df['Year'], format='%Y')

# %%
df = df.dropna()

# %% [markdown]
# **Exploratory Data Analysis**

# %%
df.describe().style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_ee30e_row0_col1, #T_ee30e_row0_col2, #T_ee30e_row0_col3, #T_ee30e_row0_col4, #T_ee30e_row0_col5, #T_ee30e_row0_col6, #T_ee30e_row0_col8, #T_ee30e_row0_col9, #T_ee30e_row0_col11, #T_ee30e_row0_col13, #T_ee30e_row0_col14, #T_ee30e_row0_col15, #T_ee30e_row0_col16, #T_ee30e_row0_col19, #T_ee30e_row0_col20, #T_ee30e_row0_col21, #T_ee30e_row0_col22, #T_ee30e_row6_col7, #T_ee30e_row6_col10, #T_ee30e_row6_col12, #T_ee30e_row6_col17, #T_ee30e_row6_col18 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ee30e_row0_col7 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_ee30e_row0_col10, #T_ee30e_row1_col18, #T_ee30e_row3_col11, #T_ee30e_row5_col5, #T_ee30e_row6_col6, #T_ee30e_row6_col22, #T_ee30e_row7_col11, #T_ee30e_row7_col13, #T_ee30e_row7_col15 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_ee30e_row0_col12 {
#   background-color: #0f5aa3;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# **Distribution of Life Expectancy using histplot across men and women**

# %%
plt.figure(figsize=(10, 6))
sns.histplot(df['Life expectancy (men)'], bins=20, kde=True, color='blue', label='Men')
sns.histplot(df['Life expectancy(women)'], bins=20, kde=True, color='pink', label='Women')
plt.xlabel('Life Expectancy')
plt.ylabel('Count')
plt.title('Distribution of Life Expectancy')
plt.legend()
plt.show()

# %% [markdown]
# **Correlation Analysis using heatmap**

# %%
corr_matrix = df.select_dtypes(include='number').corr()
plt.figure(figsize=(20, 16))
sns.heatmap(corr_matrix, annot=True, cmap='Reds')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# **Life Expectancy Trends over Time**

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(data=df, x='Year', y='Life expectancy (men)', label='Men')
sns.lineplot(data=df, x='Year', y='Life expectancy(women)', label='Women')
plt.xlabel('Year')
plt.ylabel('Life Expectancy')
plt.title('Life Expectancy Trends')
plt.legend()
plt.show()

# %% [markdown]
# **Relationship between GDP and Life Expectancy**

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='GDP', y='Life expectancy (men)', color='blue', label='Men')
sns.scatterplot(data=df, x='GDP', y='Life expectancy(women)', color='pink', label='Women')
plt.xlabel('GDP')
plt.ylabel('Life Expectancy')
plt.title('Relationship between GDP and Life Expectancy')
plt.legend()
plt.show()

# %% [markdown]
# **Histogram**

# %%
df.hist(figsize=(12, 12))
plt.tight_layout()
plt.show()

# %% [markdown]
# **Scatter plot: Life expectancy vs. GDP**

# %%
plt.scatter(df["GDP"], df["Life expectancy (men)"], label="Men", alpha=0.5)
plt.scatter(df["GDP"], df["Life expectancy(women)"], label="Women", alpha=0.5)
plt.xlabel("GDP")
plt.ylabel("Life Expectancy")
plt.title("Life Expectancy vs. GDP")
plt.legend()
plt.show()

# %% [markdown]
# **Box plot: Life expectancy by Status**

# %%
sns.boxplot(x="Status", y="Life expectancy (men)", data=df, hue="Status", palette='bright')
plt.xlabel("Status")
plt.ylabel("Life Expectancy (Men)")
plt.title("Life Expectancy by Status (Men)")
plt.show()

# %%
sns.boxplot(x="Status", y="Life expectancy(women)", data=df, hue="Status", palette='bright')
plt.xlabel("Status")
plt.ylabel("Life Expectancy (Women)")
plt.title("Life Expectancy by Status (Women)")
plt.show()

# %% [markdown]
# **Pairplot: Life expectancy and selected features**

# %%
sns.pairplot(df, vars=["Life expectancy (men)", "GDP", "Schooling"])
plt.show()

# %% [markdown]
# **Final Conclusion**
#
# *Analyzed life expectancy trends across countries using gender-wise comparison. Found that women consistently live longer than men in most countries, with significant disparities in developing regions. Key influencing factors identified include healthcare spending, adult mortality rates, and education levels. Presented insights using histograms, bar plots, and country-wise visualizations for clear stakeholder communication.*
